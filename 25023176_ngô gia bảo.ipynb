# %%
#W4A1:
n=int(input())
s=0
for x in range (1,n+1):
    s+=x
print (s)
# Out:
#  5
# 15

# %%
#W4A2:
while True:
    n=int(input())
    if n>0:
        print ('hợp lệ')
        break
    else:
        print ('k hợp lệ')
# Out:
#  -123
# k hợp lệ
